# %%
import pandas as pd
import numpy as np
from copy import deepcopy
from traceback import format_exc
# from pprint import pprint
import the_networks_of_war_python_functions

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %%
csv_directory = '/Users/the_networks_of_war/data_sources/csvs/'
csv_output_directory = '../../assets/the_networks_of_war/'
pickle_directory = '/Users/the_networks_of_war/data_sources/pickles/'

# %% [markdown]
# ## Setup for Identifying Countries by Code
# ### Note: This is helpful for when different names are used for the same country.

# %%
c_code_dic = the_networks_of_war_python_functions.define_c_code_dic()
# Out:
# Total Country Codes: 217

# %% [markdown]
# ## Integrating Descriptive Data (Defined in Outside Notebook)

# %% [markdown]
# ### Merging Participant Data with Participant-Level Descriptive Data

# %%
part_df = pd.read_pickle(pickle_directory + 'initial_part_df.pkl')
dyad_df = pd.read_pickle(pickle_directory + 'initial_dyad_df.pkl')
war_df = pd.read_pickle(pickle_directory + 'initial_war_df.pkl')

# %%
descriptive_df_1 = pd.read_pickle(pickle_directory + 'participant_descriptive_df.pkl')

descriptive_df_1.rename({'year': 'start_year'}, axis=1, inplace=True)
part_df = deepcopy(pd.merge(part_df, descriptive_df_1, how='left', on=['c_code', 'start_year']))

descriptive_df_1.rename({'start_year': 'end_year'}, axis=1, inplace=True)
part_df = deepcopy(pd.merge(part_df, descriptive_df_1, how='left', on=['c_code', 'end_year']))

# %% [markdown]
# ### Merging Dyadic Data with Dyadic-Level Descriptive Data

# %%
initial_descriptive_columns = deepcopy(set(list(dyad_df.columns)))

descriptive_df_2 = pd.read_pickle(pickle_directory + 'dyadic_descriptive_df.pkl')
dyad_df = deepcopy(pd.merge(dyad_df, descriptive_df_2, how='left', on=['c_code_a', 'c_code_b', 'year']))

print('Counting Total Dyadic War and Year Combinations by Descriptive Field\n')
the_networks_of_war_python_functions.print_new_fields(dyad_df, initial_descriptive_columns, None)
# Out:
# Counting Total Dyadic War and Year Combinations by Descriptive Field
#
#         inter_governmental_organizations  703
#                          trade_relations  618
#                                    mtops  400
#                               contiguity  317
#                    nelective_legislature  159
#                 multi_party_state_exists  139
#                      diplomatic_exchange  102
#                      colonial_contiguity   83
#                            dictatorships   83
#                                     atop   61
#                       territory_exchange   60
#                      non_elected_leaders   49
#                                 alliance   46
#           defense_cooperation_agreements   41
#                         same_leader_type   28
#                         military_leaders   21
#              no_non_regime_parties_exist   20
#            multi_party_legislature_legal   15
#                        indirect_election   13
#  no_non_regime_legislature_parties_legal   11
#            no_partisan_legislature_legal   10
#                         one_party_exists    9
#                        communist_leaders    6
#                       democratic_regimes    5
#                           no_legislature    3
#                          direct_election    2
#                single_party_state_exists    2

# %% [markdown]
# ## Finalizing Participant and Dyadic Dataframes

# %% [markdown]
# ### Keeping values for first and last year of each dyad
# ### Combining these into one row per dyad

# %%
dyad_df['year'] = dyad_df['year'].astype(float)

## creating unique identifier "conflict_pair" for each dyad
## based on name
for i, participant_a in enumerate(dyad_df['participant_a']):
    ## standardizing participant names with ccode when available
    dyad_list = []
    if dyad_df.loc[i, 'c_code_a'] in c_code_dic.keys():
        dyad_list.append(str(dyad_df.loc[i, 'c_code_a']))
    else:
        dyad_list.append(participant_a)
    if dyad_df.loc[i, 'c_code_b'] in c_code_dic.keys():
        dyad_list.append(str(dyad_df.loc[i, 'c_code_b']))
    else:
        dyad_list.append(dyad_df.loc[i, 'participant_b'])
    dyad_list = str(sorted(dyad_list))
    dyad_df.loc[i, 'conflict_pair'] = dyad_list

dyad_df_columns = ['war_num',
                   'year',
                   'participant_a',
                   'participant_b',
                   'conflict_pair']

for column in list(descriptive_df_2.columns):
    dyad_df_columns.append(column)
## not including any row without any participants
dyad_df = deepcopy(dyad_df[(dyad_df['participant_a'].isnull()==False) & (dyad_df['participant_b'].isnull()==False)])

## creating new dyad_df to get the max of each field during all the years of the dyad
max_dyad_df = deepcopy(dyad_df)
descriptive_columns =  list(descriptive_df_2.columns)
descriptive_columns.remove('year')
descriptive_columns.remove('c_code_a')
descriptive_columns.remove('c_code_b')
aggregations = {}
for column in descriptive_columns:
    max_dyad_df.rename({column: column + '_z'}, axis=1, inplace=True)
    aggregations[column + '_z'] = 'max'
max_dyad_df = deepcopy(max_dyad_df.groupby(['war_num', 'conflict_pair']).agg(aggregations).reset_index())

first_year_dyad_df = deepcopy(dyad_df)
first_year_dyad_df.sort_values(by='year', ascending=True, inplace=True)
## keeping the values for only the first year of conflict within a given dyad
## need to dedupe across conflict pair so a vs b are never repeated interchangably
first_year_dyad_df.drop_duplicates(subset=['war_num', 'conflict_pair'], keep='first', inplace=True)
first_year_dyad_df.rename({'year': 'first_year'}, axis=1, inplace=True)

last_year_dyad_df = deepcopy(dyad_df)
last_year_dyad_df.sort_values(by='year', ascending=True, inplace=True)
## keeping the values for only the last year of conflict within a given dyad
## need to dedupe across conflict pair so a vs b are never repeated interchangably
last_year_dyad_df.drop_duplicates(subset=['war_num', 'conflict_pair'], keep='last', inplace=True)
last_year_dyad_df.rename({'year': 'last_year'}, axis=1, inplace=True)

## combining first and last year dyads into one dataframe
dyad_df = deepcopy(pd.merge(first_year_dyad_df, last_year_dyad_df, how='left', on=['conflict_pair', 'war_num']))
## combining the maximum df into the final version of the dataframe
dyad_df = deepcopy(pd.merge(dyad_df, max_dyad_df, how='left', on=['conflict_pair', 'war_num']).reset_index(drop=True))
## changing column names and then dropping duplicates
## adding them into the join woudl fail (since not all have c_codes)
for column in dyad_df.columns:
    if column[-4:]=='_a_x' or column[-4:]=='_b_x':
        dyad_df.rename({column: column[:-2]}, axis=1, inplace=True)
    elif column[-4:]=='_a_y' or column[-4:]=='_b_y':
        dyad_df.drop([column], axis=1, inplace=True)

# %%
print('Counting Total Dyadic War Combinations (Overall) by Descriptive Field\n')
max_dyad_columns = list(max_dyad_df.drop(['war_num',
                                          'conflict_pair'], axis=1).columns)
the_networks_of_war_python_functions.print_new_fields(dyad_df, None, max_dyad_columns)

# print('Counting Total Dyadic War Combinations by Descriptive Field\n')
# descriptive_dyad_columns = list(dyad_df.drop(['war_num',
#                                               'c_code_a',
#                                               'c_code_b',
#                                               'participant_a',
#                                               'participant_b',
#                                               'first_year',
#                                               'last_year'], axis=1).columns)
# the_networks_of_war_python_functions.print_new_fields(dyad_df, None, descriptive_dyad_columns)
# Out:
# Counting Total Dyadic War Combinations (Overall) by Descriptive Field
#
#  Overall         inter_governmental_organizations  297
#  Overall                          trade_relations  246
#  Overall                                    mtops  181
#  Overall                               contiguity  154
#  Overall                      diplomatic_exchange   91
#  Overall                 multi_party_state_exists   63
#  Overall                                     atop   58
#  Overall                    nelective_legislature   58
#  Overall                       territory_exchange   56
#  Overall                                 alliance   43
#  Overall                      colonial_contiguity   40
#  Overall                            dictatorships   34
#  Overall           defense_cooperation_agreements   27
#  Overall                      non_elected_leaders   20
#  Overall                         military_leaders   12
#  Overall            multi_party_legislature_legal   12
#  Overall                         same_leader_type   12
#  Overall              no_non_regime_parties_exist   10
#  Overall                        indirect_election    7
#  Overall  no_non_regime_legislature_parties_legal    5
#  Overall            no_partisan_legislature_legal    5
#  Overall                         one_party_exists    5
#  Overall                        communist_leaders    4
#  Overall                       democratic_regimes    4
#  Overall                           no_legislature    2
#  Overall                single_party_state_exists    2
#  Overall                          direct_election    1

# %% [markdown]
# ### Addressing in null values, missing data, and conversions for dyads and participants

# %%
conversion_dic = {'money_flow_in': 1000000,
                  'money_flow_out': 1000000,
                  'military_expenditure': 1000,
                  'military_personnel': 1000,
                  'total_population': 1000,
                  'urban_population': 1000,
                  ## these are thousands of tons
                  'iron_steel_production': 2000000,
                  'prim_energy_consumption': 2000000
                 }
print('\nAddressng null values, missing data, and conversions for part_df.')
part_df = deepcopy(the_networks_of_war_python_functions.column_fills_and_converions(part_df, conversion_dic))

print('\nAddressng null values, missing data, and conversions for dyad_df.')
dyad_df = deepcopy(the_networks_of_war_python_functions.column_fills_and_converions(dyad_df, None))
# Out:
# Addressng null values, missing data, and conversions for part_df.
#
# Total Columns Adjusted: 32
# Total Columns Adjusted for Conversion: 16
# Total Null Values Notated: 27,561
# Total Unknown Values Notated: 476
#
# Addressng null values, missing data, and conversions for dyad_df.
#
# Total Columns Adjusted: 81
# Total Columns Adjusted for Conversion: 0

# %% [markdown]
# ### Saving the data

# %%
print('Total Participants: {}'.format(format(len(part_df), ',d')))
print('Total Dyadic Combinations: {}'.format(format(len(dyad_df), ',d')))
print('Total Wars: {}'.format(format(len(war_df), ',d')))

part_df.to_pickle(pickle_directory + 'part_df.pkl')
dyad_df.to_pickle(pickle_directory + 'dyad_df.pkl')
war_df.to_pickle(pickle_directory + 'war_df.pkl')
# Out:
# Total Participants: 1,713
# Total Dyadic Combinations: 894
# Total Wars: 678

# %%
# part_df = pd.read_pickle(pickle_directory + 'part_df.pkl')
# dyad_df = pd.read_pickle(pickle_directory + 'dyad_df.pkl')
# war_df = pd.read_pickle(pickle_directory + 'war_df.pkl')

# %% [markdown]
# ## JSON Export for D3.js Processing

# %%
war_column_list = deepcopy(list(war_df.columns))
## dropping fields that won't be needed in the participant section of the json file
## values may also differ between those in part_df and war_df.
## those in war_df have undergone additional preprocessing.
part_column_list = deepcopy(list(part_df.drop(['war_num',
                                               'war_name',
                                               'war_type',
                                               'war_sub_type',
                                               'total_deaths_both_sides'], axis=1).columns))
## dropping fields that won't be needed in the dyad section of the json file
dyad_column_list = deepcopy(list(dyad_df.drop(['war_num',
                                               'c_code_a',
                                               'c_code_b',
                                               'participant_a',
                                               'participant_b'], axis=1).columns))

print('\nUpdating/recreating one JSON file per war_num.')
print('JSON Files to be Rewritten: {}\n'.format(format(len(war_df), ',d')))

for i, war in enumerate(war_df['war_num']):
    
    file_name = deepcopy('war_num_' + str(war).replace('.', '_') + '.json')
    ## need to filter by war here because i does not follow the sorting of the dataframe
    war_df.loc[war_df['war_num']==war, 'file_name'] = file_name
    ## rewriting all of the files each time
    graph_file = open(csv_output_directory + 'json_files_by_war/' + file_name, 'w').close()
    graph_file = open(csv_output_directory + 'json_files_by_war/' + file_name, 'w')
    
    part_df_copy = deepcopy(part_df[part_df['war_num']==war].reset_index(drop=True))
    dyad_df_copy = deepcopy(dyad_df[dyad_df['war_num']==war].reset_index(drop=True))
    war_df_copy = deepcopy(war_df[war_df['war_num']==war].reset_index(drop=True))
    
    if len(part_df_copy)==0:
        print('No participants for war_num {} ({}), {} dyads'.format(war, war_df_copy.loc[0, 'war_name'], len(part_df_copy)))
    if len(dyad_df_copy)==0:
        print('No dyads for war_num {} ({}), {} participants'.format(war, war_df_copy.loc[0, 'war_name'], len(part_df_copy)))
        
    war_line = ''
    for i, column in enumerate(war_column_list):
        if i==0:
            war_line = deepcopy(war_line + '"' + column + '": "' + str(war_df_copy.loc[0, column]))
        else:
            war_line = deepcopy(war_line + '", "' + column + '": "' + str(war_df_copy.loc[0, column]))

    graph_file.write('{\n  "war": [\n    {' + war_line + '"}\n')

    node_names = []
    sides = []
    for i, participant in enumerate(part_df_copy['participant']):
        ## assigning the input based on whether a c_code is available
        ## this will be used to link part_df_copy to the dyad_df_copy
        ## (since c_code is not always availablen and participant names are not standardized)
        c_code_input = part_df_copy.loc[i, 'c_code']
        if str(c_code_input)[0] in str(np.arange(0, 10)):
            node_names.append(part_df_copy.loc[i, 'c_code'])
        else:
            node_names.append(participant)
        sides.append(part_df_copy.loc[i, 'side'])
        
    participant_line = ''
    for i, participant in enumerate(part_df_copy['participant']):
        ## this process begins the writing of the file and is completely separate from the one above
        participant_line = deepcopy(participant_line + '    {"id": "' + str(i))
        for column in part_column_list:
            participant_line = deepcopy(participant_line + '", "' + column + '": "' + str(part_df_copy.loc[i, column]))
        participant_line = deepcopy(participant_line + '"},\n')

    graph_file.write('  ],\n  "nodes": [\n' + participant_line[:-2] + '\n')

    link_line = ''
    dyad_inputs = []
    for i, node_1 in enumerate(dyad_df_copy['c_code_a']):
        ## assigning the input based on whether a c_code is available
        if str(dyad_df_copy.loc[i, 'c_code_a'])[0] in str(np.arange(0, 10)):
            node_1_input = node_1
            dyad_inputs.append(node_1)
        else:
            node_1_input = dyad_df_copy.loc[i, 'participant_a']
            dyad_inputs.append(node_1_input)
        ## assigning the input based on whether a c_code is available
        if str(dyad_df_copy.loc[i, 'c_code_b'])[0] in str(np.arange(0, 10)):
            node_2_input = dyad_df_copy.loc[i, 'c_code_b']
            dyad_inputs.append(node_2_input)
        else:
            node_2_input = dyad_df_copy.loc[i, 'participant_b']
            dyad_inputs.append(node_2_input)
        ## sometimes a country could be in the dyad and not in the participant df_copy.
        ## this is rare but has happened (see Spain in WWII)
        ## should be taken care of in processes above, so checking below to see if that process failed
        if node_1_input not in node_names:
            print("Participant Missing in Dyadic Data: {} ({}) for {}.".format(dyad_df_copy.loc[i, 'participant_a'], int(dyad_df_copy.loc[i, 'c_code_a']), war_df_copy.loc[0, 'war_name']))   
        elif node_2_input not in node_names:
            print("Participant Missing in Dyadic Data: {} {} for {}.".format(dyad_df_copy.loc[i, 'participant_b'], int(dyad_df_copy.loc[i, 'c_code_b']), war_df_copy.loc[0, 'war_name']))   
        else:
            link_line = deepcopy(link_line
                + '    {"source": "' + str(node_names.index(node_1_input))
                + '", "target": "' + str(node_names.index(node_2_input)))
            for column in dyad_column_list:
                link_line = deepcopy(link_line + '", "' + column + '": "' + str(dyad_df_copy.loc[i, column]))
            link_line = deepcopy(link_line + '"},\n')
            ## checking for any dyads that are paired with participants on the same side as them
            ## this would most likely suggest a mistake in pre-processing
            ## does not apply to side 3 (switched sides)
            if sides[node_names.index(node_1_input)]==sides[node_names.index(node_2_input)] and sides[node_names.index(node_1_input)]!=3:
                print('Dyads on the Same Side: {} {} and {} {} for {}.'.format(dyad_df_copy.loc[i, 'participant_a'], int(dyad_df_copy.loc[i, 'c_code_a']), dyad_df_copy.loc[i, 'participant_b'], int(dyad_df_copy.loc[i, 'c_code_b']), war_df_copy.loc[0, 'war_name']))   
                         
    graph_file.write('  ],\n  "links": [\n' + link_line[:-2] + '\n\n  ]\n}')

    for node in node_names:
        if node not in dyad_inputs:
            if int(str(node)[0]) in np.arange(0, 10):
                print('Floating Node in {}: {}'.format(war_df_copy.loc[0, 'war_name'],
                                                       c_code_dic[node]))
            else:
                print('Floating Node in {}: {}'.format(war_df_copy.loc[0, 'war_name'],
                                                       node))
                
print('\nCompleted JSON File Updates.')

print('\nUpdating war_file_list.csv')
war_df.to_csv(csv_output_directory + 'war_file_list.csv', index=None)
print('\nCompleted war_file_list update.')
# Out:
# Updating/recreating one JSON file per war_num.
# JSON Files to be Rewritten: 678
#
# Floating Node in Donbas War: Russia
# Floating Node in Somali-Al-Shabaab war: United States of America
# Floating Node in Somali-Al-Shabaab war: Uganda
# Floating Node in Somali-Al-Shabaab war: Kenya
# Floating Node in Somali-Al-Shabaab war: Burundi
# Floating Node in Somali-Al-Shabaab war: Ethiopia
# Floating Node in Afghan-Taliban War: United States of America
# Floating Node in South Sudan War: Uganda
# Floating Node in Boko Haram in Nigeria: Chad
# Floating Node in Central African Republic War: Chad
# Floating Node in North Mali War: France
# Floating Node in North Mali War: Nigeria
# Floating Node in North Mali War: Chad
# Floating Node in Syrian Arab Spring War: Iran
# Floating Node in Second Cote d'Ivoire War: France
# Floating Node in Libyan Civil War: United States of America
# Floating Node in Libyan Civil War: United Kingdom
# Floating Node in Libyan Civil War: France
# Floating Node in Libyan Civil War: Canada
# Floating Node in Libyan Civil War: Italy
# Floating Node in Libyan Civil War: Spain
# Floating Node in Iraqi Sunni Revolt: United States of America
# Floating Node in Second Waziristan War: United States of America
# Floating Node in Third Somalia War: United States of America
# Floating Node in Third Somalia War: Uganda
# Floating Node in Third Somalia War: Burundi
# Floating Node in Third Somalia War: Ethiopia
# Floating Node in Third Somalia War: Eritrea
# Floating Node in Chad-United Opposition War: France
# Floating Node in First Waziristan War: United States of America
# Floating Node in Iraqi Resistance: Australia
# Floating Node in Iraqi Resistance: United Kingdom
# Floating Node in Iraqi Resistance: Netherlands
# Floating Node in Iraqi Resistance: Spain
# Floating Node in Iraqi Resistance: Poland
# Floating Node in Iraqi Resistance: Italy
# Floating Node in Iraqi Resistance: Ukraine
# Floating Node in Iraqi Resistance: Iraq
# Floating Node in Cote d'Ivoire Military War: France
# Floating Node in Afghan Resistance: France
# Floating Node in Afghan Resistance: Australia
# Floating Node in Afghan Resistance: Germany
# Floating Node in Afghan Resistance: United Kingdom
# Floating Node in Afghan Resistance: Canada
# Floating Node in Afghan Resistance: Afghanistan
# Floating Node in Third Burundi War: Rwanda
# Floating Node in Invasion of Afghanistan: Canada
# Floating Node in Invasion of Afghanistan: France
# Floating Node in Invasion of Afghanistan: Australia
# Floating Node in War for Kosovo: United Kingdom
# Floating Node in War for Kosovo: Netherlands
# Floating Node in War for Kosovo: France
# Floating Node in War for Kosovo: Germany
# Floating Node in War for Kosovo: Italy
# Floating Node in War for Kosovo: Turkey
# Floating Node in Third Angolan War: Namibia
# Floating Node in Africa's World War: Central African Republic
# Floating Node in Africa's World War: Chad
# Floating Node in Africa's World War: Angola
# Floating Node in Africa's World War: Zimbabwe
# Floating Node in Africa's World War: Sudan
# Floating Node in Africa's World War: Rwanda
# Floating Node in Africa's World War: Burundi
# Floating Node in Africa's World War: Uganda
# Floating Node in Second Sierra Leone War: Ghana
# Floating Node in Second Sierra Leone War: Nigeria
# Floating Node in Second Sierra Leone War: Guinea
# Floating Node in Second Sierra Leone War: United Kingdom
# Floating Node in Second Congo-Brazzaville War: Angola
# Floating Node in Guinea-Bissau Military War: Senegal
# Floating Node in Guinea-Bissau Military War: Guinea
# Floating Node in First Congo-Brazzaville War: Angola
# Floating Node in Zaire - AFDL War: Uganda
# Floating Node in Zaire - AFDL War: Burundi
# Floating Node in Zaire - AFDL War: Rwanda
# Floating Node in Zaire - AFDL War: Angola
# No dyads for war_num 217.0 (Cenepa Valley), 2 participants
# Floating Node in Cenepa Valley: Ecuador
# Floating Node in Cenepa Valley: Peru
# Floating Node in Tajikistan War: Russia
# Floating Node in Second Liberian War: Guinea
# Floating Node in Second Liberian War: Ghana
# Floating Node in Second Liberian War: Nigeria
# Floating Node in Bosnian-Serb Rebellion: United States of America
# Floating Node in Bosnian-Serb Rebellion: Croatia
# Floating Node in Abkhazia Revolt: Russia
# No dyads for war_num 215.0 (Bosnian Independence), 3 participants
# Floating Node in Bosnian Independence: Croatia
# Floating Node in Bosnian Independence: Yugoslavia
# Floating Node in Bosnian Independence: Bosnia and Herzegovina
# Floating Node in Second Somalia War: United States of America
# Floating Node in Second Somalia War: Canada
# Floating Node in Second Somalia War: France
# Floating Node in Second Somalia War: Italy
# Floating Node in Second Somalia War: Nigeria
# Floating Node in Second Somalia War: Pakistan
# Floating Node in First Sierra Leone War: Nigeria
# Floating Node in Nagorno-Karabakh War: Armenia
# Floating Node in Dniestrian Independence War: Russia
# Floating Node in Gulf War: Morocco
# Floating Node in Gulf War: Oman
# Floating Node in First Liberian War: Guinea
# Floating Node in First Liberian War: Nigeria
# Floating Node in Fifth Lebanese War: Syria
# Floating Node in Fifth Iraqi Kurds War: Iran
# Floating Node in Second South Sudan War: Libya
# Floating Node in Second South Sudan War: Uganda
# Floating Node in Fourth Lebanese War: United States of America
# Floating Node in Fourth Lebanese War: France
# Floating Node in Fourth Lebanese War: Iran
# Floating Node in Fourth Lebanese War: Syria
# Floating Node in Mozambique War: Cuba
# Floating Node in Mozambique War: Tanzania
# Floating Node in Soviet Quagmire: Afghanistan
# Floating Node in Chad - FAN War: Libya
# Floating Node in Chad - FAN War: France
# Floating Node in Chad - FAN War: Democratic Republic of the Congo
# Floating Node in Khmer Insurgency: Cambodia
# Floating Node in Mujahideen Uprising: Russia
# Floating Node in Second Ogaden War phase 3: Cuba
# Floating Node in Second Ogaden War phase 3: Somalia
# Floating Node in Zaire-FNLC War: Belgium
# Floating Node in Zaire-FNLC War: France
# Floating Node in Third Lebanese War: Israel
# Floating Node in Third Lebanese War: Syria
# Floating Node in Chad - FAP War: France
# Floating Node in Chad - FAP War: Libya
# Floating Node in Angolan Control War: Cuba
# Floating Node in Angolan Control War: South Africa
# Floating Node in Second Laotian War: Vietnam
# Floating Node in Second Ogaden War phase 1: Somalia
# Floating Node in Western Saharan: Algeria
# Floating Node in Eritrean War: Cuba
# Floating Node in Second Lebanese War: Syria
# Floating Node in Fourth Iraqi Kurds War: Iran
# Floating Node in Dhofar Rebellion phase 2: United Kingdom
# Floating Node in Dhofar Rebellion phase 2: Iran
# Floating Node in First Khmer Rouge War: United States of America
# Floating Node in First Khmer Rouge War: Republic of Vietnam
# Floating Node in First Khmer Rouge War: Vietnam
# Floating Node in Pakistan - Bengal War: India
# Floating Node in Communist Coalition: United States of America
# Floating Node in Communist Coalition: Republic of Vietnam
# Floating Node in Black September War: Syria
# Floating Node in Second Laotian, Phase 2: United States of America
# Floating Node in Second Laotian, Phase 2: Thailand
# Floating Node in First Chad Rebellion: France
# Floating Node in First Guatemala War: United States of America
# Floating Node in Third Burmese War: China
# Floating Node in Vietnam War, Phase 2: Cambodia
# Floating Node in Dominican Republic War: United States of America
# Floating Node in Third DRC Rebellion: Belgium
# Floating Node in First South Sudan War: Egypt
# Floating Node in First Ogaden War: Somalia
# Floating Node in First Iraqi Kurds War: Syria
# Floating Node in Vietnam War phase 1: United States of America
# Floating Node in Vietnam War phase 1: Vietnam
# Floating Node in First DRC War: Belgium
# Floating Node in First Laotian War: United States of America
# Floating Node in First Laotian War: Vietnam
# Floating Node in First Lebanese War: United States of America
# Floating Node in First Lebanese War: Syria
# No dyads for war_num 158.0 (IfniWar), 3 participants
# Floating Node in IfniWar: France
# Floating Node in IfniWar: Spain
# Floating Node in IfniWar: Morocco
# Floating Node in Greek Civil War round 3: United Kingdom
# Floating Node in Polish Ukrainians War: Poland
# Floating Node in Indonesian: United Kingdom
# Floating Node in Greek Civil War round 2: United Kingdom
# No dyads for war_num 145.0 (Franco-Thai), 2 participants
# Floating Node in Franco-Thai: France
# Floating Node in Franco-Thai: Thailand
# Floating Node in Spanish Civil War: Russia
# Floating Node in Spanish Civil War: Portugal
# Floating Node in Spanish Civil War: Germany
# Floating Node in Spanish Civil War: Italy
# Floating Node in Xinjiang Revolt: Russia
# Floating Node in Mongolian Armed Uprising: Russia
# Floating Node in Chinese Northern Expedition: Japan
# Floating Node in Rif Rebellion: France
# Floating Node in Conquest of Mongolia: Russia
# Floating Node in Gilan Marxists Rebellion: United Kingdom
# Floating Node in Gilan Marxists Rebellion: Russia
# Floating Node in Western Ukrainian War: Poland
# Floating Node in Finnish Civil War: Germany
# Floating Node in Finnish Civil War: Russia
# Floating Node in Russian Civil War: Finland
# Floating Node in Russian Civil War: Japan
# Floating Node in Russian Civil War: United Kingdom
# Floating Node in Russian Civil War: United States of America
# Floating Node in Russian Civil War: France
# Floating Node in Fourth Mexican War: United States of America
# Floating Node in World War I: Japan
# Floating Node in Third Mexican War: United States of America
# Floating Node in Iranian Constitution War: Russia
# Floating Node in Hafiziyya Uprising: France
# Floating Node in Somali Rebellion: Ethiopia
# Floating Node in Colombian War of the Thousand Days: Venezuela
# Floating Node in Colombian War of the Thousand Days: Ecuador
# Floating Node in Tonghak Rebellion phase 1: China
# Floating Node in Third Franco-Vietnamese: China
# Floating Node in First British-Mahdi: Egypt
# Floating Node in Shimonoseki War: United Kingdom
# Floating Node in Shimonoseki War: Netherlands
# Floating Node in Shimonoseki War: France
# Floating Node in Taiping Rebellion phase 2: United Kingdom
# Floating Node in Second Opium: France
# Floating Node in Hungarian War: Russia
# Floating Node in Patuleia War: Spain
# Floating Node in Cracow Revolt: Russia
# Floating Node in Uruguay War: United Kingdom
# Floating Node in Uruguay War: France
# Floating Node in Third Syrian War: United Kingdom
# Floating Node in First Carlist War: United Kingdom
# Floating Node in First Carlist War: France
# Floating Node in First Carlist War: Portugal
# Floating Node in Miguelite War: United Kingdom
# Floating Node in Greek Independence War: United Kingdom
# Floating Node in Greek Independence War: France
# Floating Node in Greek Independence War: Russia
# Floating Node in Sardinian Revolt: Austria-Hungary
# Floating Node in First Two Sicilies War: Austria-Hungary
# Floating Node in Allied Bombardment of Algiers: Netherlands
#
# Completed JSON File Updates.
#
# Updating war_file_list.csv
#
# Completed war_file_list update.
